# %%
# !git clone https://github.com/TmohamedashrafT/Yolov4-implementation.git
# Out:
# Cloning into 'Yolov4-implementation'...
# remote: Enumerating objects: 206, done.
# remote: Counting objects: 100% (117/117), done.
# remote: Compressing objects: 100% (116/116), done.
# remote: Total 206 (delta 62), reused 0 (delta 0), pack-reused 89
# Receiving objects: 100% (206/206), 72.36 KiB | 4.52 MiB/s, done.
# Resolving deltas: 100% (101/101), done.

# %%
# %cd Yolov4-implementation
# Out:
# /kaggle/working/Yolov4-implementation/Yolov4-implementation

# %%
with open(f"data.yaml", "w+") as file_:
  file_.write(
           f"""
           train_image_path : '/kaggle/working/BCCD-794/train/images/'
           train_ann_path   : '/kaggle/working/BCCD-794/train/labels/'
           val_image_path : '/kaggle/working/BCCD-794/valid/images/' 
           val_ann_path   : '/kaggle/working/BCCD-794/valid/labels' 
           test_image_path : '/kaggle/working/BCCD-794/test/images/' 
           test_ann_path : '/kaggle/working/BCCD-794/test/labels/' 
           num_classes : 3
           classes : ['Platelets','RBC','WBC']
            """
)

# %%
# !python Training.py --data data.yaml --hyp yamls/hyp.yaml --aug yamls/aug.yaml
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# loading the model
# loading the data
# ################ Start  Training ################
# Training: 100%|#################################| 16/16 [00:10<00:00,  1.51it/s]
# epoch 0/100 box loss =  470.165   conf loss =  17353.628   cls loss =  237.779
#
# instances 73    mAP@IoU 0.50 =  0.004   mAP@IoU 0.50:0.95 =  0.001
#
# Training: 100%|#################################| 16/16 [00:05<00:00,  2.71it/s]
# epoch 1/100 box loss =  443.935   conf loss =  5491.54   cls loss =  140.062
#
# instances 73    mAP@IoU 0.50 =  0.005   mAP@IoU 0.50:0.95 =  0.001
#
# Training: 100%|#################################| 16/16 [00:05<00:00,  2.84it/s]
# epoch 2/100 box loss =  408.793   conf loss =  3199.135   cls loss =  115.962
#
# ...

# %%
# !python eval.py --data data.yaml --task 'train' --weights 'best.pt'
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# instances 255    mAP@IoU 0.50 =  0.937   mAP@IoU 0.50:0.95 =  0.606

# %%
# !python eval.py --data data.yaml --task 'val' --weights 'best.pt'
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# instances 73    mAP@IoU 0.50 =  0.892   mAP@IoU 0.50:0.95 =  0.567

# %%
# !python eval.py --data data.yaml --task 'test' --weights 'best.pt'
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# instances 36    mAP@IoU 0.50 =  0.877   mAP@IoU 0.50:0.95 =  0.524

# %%
# !python '/kaggle/working/Yolov4-implementation/Yolov4-implementation/Yolov4-implementation/predict.py' --src '/kaggle/working/BCCD-794/test/images/BloodImage_00369_jpg.rf.09cb727efd31232caa3558dc54a90c09.jpg'  --weights 'best.pt' --conf_thresh 0.4
# Out:
# prediction speed =  1.1816744804382324 NMS speed =  0.0016622543334960938

# %%
import matplotlib.pyplot as plt
import cv2

# %%
test_img = cv2.imread('test.jpg')

# %%
plt.imshow(img)
